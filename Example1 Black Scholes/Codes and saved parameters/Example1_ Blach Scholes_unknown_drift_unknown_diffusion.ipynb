# %%
#Import Libraries
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
import torchvision.transforms as transforms
from sklearn.metrics import mean_absolute_error as mae
mse = nn.MSELoss()
import torch.optim.lr_scheduler as lr_scheduler
device=device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import seaborn as sns
from scipy.integrate import solve_ivp
import math

# %% [markdown]
# Euler Maruyama SDE Solver for Data Generation

# %%
def Euler_Maruyama(param,dt,n):
    [p1,p2] = param
    sol = np.zeros(n)
    sol[0] = 1
    for i in range(n-1):
        sol[i+1] = sol[i] +  p1*sol[i]*dt +  p2*sol[i]*np.random.randn(1)*np.sqrt(dt)
    return sol

# %% [markdown]
# Data Generation

# %%
#Uniform random initialization of parameters x1 and x2 for 3500 data points
x1=np.random.uniform(0,0.1,3500)
x2=np.random.uniform(0,0.4,3500)
print(x1[2])

#Standard Deviation for x1 and x2
std_x1 = np.std(x1)
std_x2 = np.std(x2)

#Time discretization domain 
t = np.linspace(0,0.1,100)
dt = t[2]-t[1]
print(dt)

S=np.zeros([3500,100])
prm =np.zeros([3500,2]) 

for i in range(3500):
    z=np.random.randn(100)
    if i%50 == 0: # Each parameter has been replcated 50 times to produe 50 stochastic outputs
        p1 = x1[i]
        p2 = x2[i]
    param = [p1,p2]
    S[i,:]= Euler_Maruyama(param,dt,100)
    prm[i] = param
print(np.shape(S))
print(prm.shape)

#plot pdf
plt.figure(1)
plt.plot(t, S[10,:], label='s')
txt = "x1="+str(prm[10,0])[0:7]+" x2=" + str(prm[10,1])[0:7]
plt.title(label=txt)
plt.xlabel('Time (s)')
plt.legend()
plt.grid(True)
# Out:
# 0.059730189156725746
# 0.00101010101010101
# (3500, 100)
# (3500, 2)

# %%
#Pdf of generated data at a particular time step
S_at_t = S[:,33]
print(prm[0])
sns.kdeplot(S_at_t)
# Out:
# [0.00764997 0.18599441]
# <AxesSubplot:ylabel='Density'>

# %%
#Preparing training dataset and dataloader

train_data = torch.from_numpy(S[0:2000,:]).to(device)
train_prm  = torch.from_numpy(prm[0:2000,:]).to(device)

Train_data = TensorDataset(train_data,train_prm)
Train_dl = DataLoader(Train_data, batch_size=50, shuffle=False) # We didn’t shuffle the data to club

# %% [markdown]
# Deep Neural network for proposed approach

# %%
class DNN(nn.Module):
    def __init__(self):
        super(DNN, self).__init__()
        
        # Neural network that will fill in for drift term
        self.fp1 = nn.Sequential(nn.Linear(13,64),
                                nn.ELU(),
                                nn.Linear(64 ,256),
                                nn.ELU(),
                                nn.Linear(256,512),
                                nn.ELU(),
                                nn.Linear(512,256),
                                nn.ELU(),
                                nn.Linear(256, 64),
                                nn.ELU(),
                                nn.Linear(64,1))
        
        # Neural network that will fill in for diffusion term
        self.fA1 = nn.Sequential(nn.Linear(13, 64),
                                 nn.ELU(),
                                 nn.Linear(64 ,256),
                                 nn.ELU(),
                                 nn.Linear(256,512),
                                 nn.ELU(),
                                 nn.Linear(512,256),
                                 nn.ELU(),
                                 nn.Linear(256, 64),
                                 nn.ELU(),
                                 nn.Linear(64,1))
       


    def forward(self, batch_size, params,n):
        zp = params
        
        #Initializing the solution matrix
        s_dash = torch.zeros((batch_size,n),dtype = float).to(device) 
        
        #As the initial condition s_dash(@ t=0) = 1, assigning first column of s_dash as 1
        s_dash[:,0] = torch.ones((batch_size), dtype = float).to(device)
        
        #Loop for time marching
        for i in range(n-1):
            s = torch.reshape(s_dash[:,i],(batch_size,1))
            
            # Taking sample for Z(random variable) from standard gaussian distribution
            z_A1 = torch.randn(batch_size,10).to(device)
            
            #Taking out 1st column out from the parameters i.e x1 and calling it z_p0
            z_p0 = torch.reshape(zp[:,0],(batch_size,1))
            
            #Taking out 2nd column out from the parameters i.e x1 and calling it z_p1
            z_p1 = torch.reshape(zp[:,1],(batch_size,1))
            
            #Input to the Neural network that will replace drift part
            input_fp1 = torch.cat((z_A1,z_p1,z_p0,s),1).to(device)
            
            #Input to the Neural network that will replace diffusion part
            input_fA1 = torch.cat((z_A1,z_p1,z_p0,s),1).to(device)
            
            # Outputs from the two neural networks
            fA1_loc = self.fA1(input_fA1)
            fp1_loc = self.fp1(input_fp1)
            
            #Resize
            fA1_loc_ = torch.squeeze(fA1_loc)
            fp1_loc_ = torch.squeeze(fp1_loc)

            # Time as tensor  of size = batch size
            dT = dt * torch.ones(batch_size).to(device)
            
            # White noise as tensor of size = batch size
            dW = torch.randn(batch_size).to(device)
            
            # Using explicit Euler Maruyama to compute the output at (i+1)th step given the ith step soutput
            s_dash[:,i+1] = s_dash[:,i] + dT*fp1_loc_ + fA1_loc_*dW*torch.sqrt(dT)
           
        s_hat = s_dash
        
        return s_hat, zp

# %% [markdown]
# Loss Function

# %%
def gram_matrix(x, y, gamma1, pi1):
    sq_dist = torch.sum((torch.unsqueeze(x, 1)-torch.unsqueeze(y, 0))**2,2)  
    kernel = (pi1*torch.exp(-gamma1*sq_dist))
    return  kernel

# %%
def multidot(A,B,C,D):

  return torch.tensordot(A,torch.tensordot(B,torch.tensordot(C,D,dims=1),dims=1),dims=1)

# %%
def CMMD_loss(x_comp, x_hat, params, zp):
    
        #Mixture Coefficients 
        gamma1 = torch.sigmoid(lambda1)  
        pi1 = torch.exp(beta1).to(device)
        #Gram Matrices
        k_d = gram_matrix(params, params, gamma1, pi1)
        #print('k_d',k_d.shape)
        k_s = gram_matrix(zp, zp, gamma1, pi1)
        #print('k_s',k_s)
        l_d = gram_matrix(x_comp, x_comp, gamma1, pi1)
        #print('l_d',l_d)
        l_s = gram_matrix(x_hat, x_hat, gamma1, pi1)
        #print('l_s',l_s)
        k_sd = gram_matrix(params,zp, gamma1, pi1)
        #print('k_sd',k_sd)
        l_ds = gram_matrix(x_comp, x_hat, gamma1, pi1)
        #print('l_ds',l_ds)
        lam = 2.0 #hyperparameteR
        row, col = k_d.shape
        k_d_tilda = k_d + (lam*torch.eye(row,col,device="cuda"))
        #print( 'k_d_tild',k_d_tilda)
        k_s_tilda = k_s + (lam*torch.eye(row,col,device="cuda"))
        #print(' k_s_tilda',k_s_tilda)
        k_sd_tilda = k_sd + (lam*torch.eye(row,col,device="cuda"))
        #print('k_sd_tilda',k_sd_tilda)
        loss = torch.sqrt(torch.trace(multidot(k_d,torch.inverse(k_d_tilda),l_d,torch.inverse(k_d_tilda))) + torch.trace(multidot(k_s,torch.inverse(k_s_tilda),l_s,torch.inverse(k_s_tilda))) - 2*torch.trace(multidot(k_sd,torch.inverse(k_d_tilda),l_ds,torch.inverse(k_s_tilda))))
        #print('shape',loss.shape)
        return loss

# %% [markdown]
# Training with MSE error as the loss function

# %%
def train(autoencoder, epochs):
    opt = torch.optim.Adam(autoencoder.parameters(),lr = .001)
    train_loss_epochs = torch.empty((epochs)).to(device)
    scheduler = lr_scheduler.StepLR(opt, step_size=500, gamma=0.9, verbose = True)
    for epoch in range(epochs):
        print(epoch)
        a=1
        b=1
        i=0
        train_cum_loss = 0
        for batch,params in Train_dl:
            s = batch  
            batch_size = s.shape[0]
            x1 = params[:,0] # since params is taking new set of values every iterations 
            x2 =  params[:,1]
            opt.zero_grad()
            s_hat,zp = autoencoder(s, x1=x1, x2=x2, batch_size=batch_size)
            i=+1
            loss_rec = ((s - s_hat)**2).sum()
            loss_kl =  autoencoder.encoder.kl
            loss = ((s - s_hat)**2).sum() + autoencoder.encoder.kl 
            train_cum_loss+=loss
            loss.backward()
            opt.step()
        scheduler.step()
        print("loss_rec",loss_rec)
        print("loss_kl",loss_kl)
        train_loss_epochs[epoch] = train_cum_loss/2000 #bATCH_SIZE
    return autoencoder, train_loss_epochs,opt

# %% [markdown]
# Training with CMMD as loss function

# %%
def train_CMMD(autoencoder, epochs):
    opt = torch.optim.Adam(autoencoder.parameters(),lr = .00001)
    train_loss_epochs = torch.empty((epochs)).to(device)
    scheduler = lr_scheduler.StepLR(opt, step_size = 500, gamma=0.9, verbose = True)
    for epoch in range(epochs):
        print(epoch)
        a=1
        b=1
        c=10
        i=0
        train_cum_loss = 0
        for batch,params in Train_dl:
           s = batch
           params = params[:,0:2]
           batch_size = s.shape[0]
           x1 = params[:,0] # since params is taking new set of values every iterations 
           #print("omega",omega.shape)
           x2 =  params[:,1]
           opt.zero_grad()
           s_hat,zp = autoencoder(batch_size=batch_size, params = params, n=100)
           i=+1
           loss_CMMD = CMMD_loss(s, s_hat, params, params)
           loss_rec = ((s - s_hat)**2).sum()
           loss = a*loss_CMMD 
           train_cum_loss+=loss
           loss.backward()
           opt.step()
        scheduler.step()
        train_loss_epochs[epoch] = train_cum_loss/2000 #bATCH_SIZE
        print("loss_CMMD",loss_CMMD)
        print("loss_rec",loss_rec)
    return autoencoder, train_loss_epochs, opt

# %% [markdown]
# Testing by generating random parameters

# %%
def test(autoencoder,n):
    x1=np.random.uniform(0,0.1,1500)
    x2=np.random.uniform(0,0.4,1500)
    t = np.linspace(0,0.1,100)
    dt = .001
    S=np.zeros([1500,n])
    prm_test =np.zeros([1500,2]) 
    for i in range(1500):
        q1 = x1[i]
        q2 = x2[i]
        param = [q1,q2]
        S[i,:]= Euler_Maruyama(param,dt,n)
        prm_test[i] = param
    print(S.shape)
    print(prm_test.shape)
    test_data1 = torch.from_numpy(S).to(device) 
    test_prm1 = torch.from_numpy(prm_test).to(device)
    Test_data1 = TensorDataset(test_data1,test_prm1)
    Test_dl_1 = DataLoader(Test_data1, batch_size=50, shuffle=False)
    with torch.no_grad():  
        s_full =  torch.empty(1500,n)
        s_hat_full =  torch.empty(1500,n)
        parameters =  torch.empty(1500,2) 
        i=0
        for batch,p in Test_dl_1:
            s = batch
            #print("s_shape",s.shape)
            batch_size = s.shape[0]
            parameters[i*batch_size:(i+1)*batch_size,:] = p
            #print(batch_size)
            s_full[i*batch_size:(i+1)*batch_size,:] = s
            s_hat,zp = autoencoder(batch_size=batch_size, params = p, n=n)
            s_hat_full[i*batch_size:(i+1)*batch_size,:] = s_hat
            i+=1
        x_hat = s_hat_full.cpu()
        X_hat = x_hat.detach().numpy()
        x = s_full.cpu()
        X= x.detach().numpy()
        er = mae = np.absolute(np.subtract(X_hat, X)).mean() 

    return er,parameters,X_hat,X

# %% [markdown]
# MAIN

# %%
# No of epochs for training
epochs = 200

# lambda1 and beta1 are the parameters in the kernel function used to define the CMMD loss function
lambda1 = torch.tensor(-0.5, requires_grad = True).to(device)
beta1 = torch.tensor(4.0, requires_grad = True).to(device)

#Included in the training process
lambda1 = torch.nn.Parameter(lambda1)
beta1 = torch.nn.Parameter(beta1)

#Calling the DNN class and registering lambda1 and beta1 as learnable parameters
model = DNN().to(device)
model.register_parameter('lanbda11',lambda1)
model.register_parameter('beta1',beta1)

#Training
model,train_loss_epochs,opt= train_CMMD(model.double(),epochs)

#plotting training loss vs number of epochs at the end of the training
epochs_array = np.linspace(0,epochs,epochs)
train_loss_epochs= train_loss_epochs.cpu()
train_loss_epochs= train_loss_epochs.detach().numpy()
fig1=plt.figure(1)
plt.plot(epochs_array ,train_loss_epochs, label="training_loss")
plt.xlabel("Epochs")
plt.ylabel("Training loss")
# Out:
# Adjusting learning rate of group 0 to 1.0000e-05.
# 0
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0716, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(6.2406, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 1
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0644, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(6.8746, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 2
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0700, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(7.4492, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 3
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0834, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(12.1133, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 4
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1148, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(14.0410, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 5
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0779, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(12.1788, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 6
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0705, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(8.9230, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 7
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0616, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(9.1207, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 8
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0856, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(11.6905, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 9
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0594, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(10.4949, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 10
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0952, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(13.1990, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 11
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0955, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(12.7195, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 12
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0799, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(11.2165, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 13
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0758, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(11.8547, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 14
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0717, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(8.2882, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 15
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1065, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(11.5519, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 16
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0447, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(8.0401, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 17
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0894, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(11.2338, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 18
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0876, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(13.4872, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 19
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0790, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(10.7984, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 20
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1008, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(11.0929, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 21
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1023, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(12.1623, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 22
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0862, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(11.6956, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 23
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0873, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(9.5814, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 24
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0759, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(10.6387, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 25
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0835, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(8.6610, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 26
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0854, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(13.2778, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 27
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0623, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(10.7091, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 28
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0730, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(10.2587, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 29
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1196, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(12.8821, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 30
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1061, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(12.4492, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 31
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0577, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(8.2289, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 32
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0827, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(9.1100, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 33
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0630, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(9.7206, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 34
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0862, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(10.3554, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 35
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0432, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(6.9300, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 36
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0524, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(9.9048, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 37
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0539, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(7.8700, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 38
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0728, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(7.2500, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 39
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0423, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(7.1239, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 40
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0601, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(10.2109, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 41
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0751, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(9.2744, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 42
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0906, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(10.5720, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 43
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0692, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(8.7417, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 44
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0468, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(7.7790, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 45
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0436, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(7.9162, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 46
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0506, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(6.7120, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 47
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0416, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(7.1078, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 48
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0450, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(7.1907, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 49
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0501, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(6.6477, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 50
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0820, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(6.7999, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 51
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0583, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(7.2560, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 52
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0377, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.7041, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 53
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0532, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(6.1079, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 54
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0336, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(6.6507, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 55
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0306, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(6.5467, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 56
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0534, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(7.4399, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 57
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0428, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(7.9837, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 58
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0370, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.7816, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 59
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0205, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.1598, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 60
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0335, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.8194, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 61
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0205, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.0886, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 62
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0145, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.2790, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 63
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0119, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(3.2187, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 64
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0377, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.0275, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 65
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0273, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.7880, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 66
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0340, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.7207, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 67
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0265, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.1836, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 68
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0383, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(6.3228, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 69
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0250, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.2401, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 70
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0281, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.0269, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 71
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0296, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.1082, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 72
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0159, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.2197, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 73
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0476, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.6751, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 74
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0222, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.2959, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 75
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0591, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.9988, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 76
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0368, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.6374, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 77
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0185, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.2025, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 78
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0283, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.5132, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 79
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0157, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.5937, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 80
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0591, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(3.5529, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 81
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0681, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.5485, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 82
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0220, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.7191, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 83
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0310, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.4815, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 84
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0344, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.8486, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 85
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0221, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.5520, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 86
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0391, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.9108, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 87
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0235, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(3.5919, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 88
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0143, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.1259, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 89
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0167, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.5309, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 90
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0331, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.9784, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 91
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0149, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.6637, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 92
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0402, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.0155, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 93
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0237, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.3178, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 94
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0273, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.9459, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 95
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0248, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.4060, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 96
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0324, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.1240, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 97
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0377, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.3459, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 98
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0201, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.6391, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 99
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0300, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.4965, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 100
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0405, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.5982, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 101
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0177, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.7287, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 102
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0679, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.3610, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 103
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0360, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.5608, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 104
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0529, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.3133, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 105
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0476, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.6428, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 106
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0245, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.9914, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 107
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0134, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(3.9352, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 108
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0297, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.4117, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 109
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0478, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.4994, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 110
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0205, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.4070, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 111
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0141, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.9376, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 112
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0159, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.5256, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 113
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0194, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(3.9184, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 114
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0096, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(3.5403, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 115
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0437, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.6845, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 116
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0383, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.4405, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 117
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0242, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.7479, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 118
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0221, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.2705, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 119
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0623, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.7723, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 120
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0113, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.2512, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 121
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0225, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.4488, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 122
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0219, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.6074, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 123
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0613, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.9741, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 124
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0307, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.9118, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 125
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0242, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(3.5919, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 126
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0205, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.2951, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 127
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0144, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.6122, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 128
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0145, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(3.9564, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 129
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0263, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(3.3787, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 130
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0268, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(6.4182, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 131
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0269, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.4936, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 132
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0123, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.7575, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 133
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0194, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.5551, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 134
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0621, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.7544, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 135
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0382, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.0437, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 136
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0558, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.6270, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 137
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0266, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.7307, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 138
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0200, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.1486, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 139
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0212, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.4511, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 140
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0121, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.1091, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 141
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0206, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.4990, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 142
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0251, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(3.0820, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 143
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0437, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.5498, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 144
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0125, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.0170, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 145
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0241, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.5194, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 146
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0281, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.3862, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 147
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0279, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.9271, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 148
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0142, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.2180, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 149
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0260, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.0763, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 150
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0521, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(3.8058, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 151
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0422, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.3338, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 152
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0145, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.1354, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 153
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0327, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.8740, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 154
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0256, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.4296, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 155
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0280, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.7833, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 156
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0556, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.3197, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 157
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0172, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.4086, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 158
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0254, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.9547, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 159
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0207, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.2870, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 160
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0577, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(3.2051, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 161
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0248, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.7876, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 162
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0412, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(3.5633, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 163
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0131, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.6232, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 164
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0200, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.9760, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 165
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0329, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.2637, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 166
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0511, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.5717, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 167
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0658, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.6347, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 168
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0243, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.4684, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 169
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0467, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(3.7794, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 170
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0271, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(3.4577, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 171
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0118, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(3.8379, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 172
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0410, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(6.8271, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 173
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0537, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.4162, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 174
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0648, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.6909, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 175
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0255, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.2677, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 176
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0213, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(3.5224, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 177
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0261, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(3.7619, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 178
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0234, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(6.7082, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 179
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0339, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.7099, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 180
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0131, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.0619, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 181
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0323, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(3.3725, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 182
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0355, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.7651, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 183
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0225, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.1278, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 184
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0522, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.9960, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 185
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0442, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.6484, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 186
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0633, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.2048, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 187
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0132, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.1992, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 188
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0164, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(6.1568, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 189
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0261, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(3.6668, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 190
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0575, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.4717, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 191
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0321, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.0412, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 192
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0220, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.6194, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 193
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0341, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.6549, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 194
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0533, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.7613, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 195
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0099, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(3.9094, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 196
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0259, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.2297, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 197
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0178, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.3358, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 198
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0405, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(5.9489, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 199
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.0167, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(4.3218, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# Text(0, 0.5, 'Training loss')

# %%
#Saving the traind model
torch.save(model.state_dict(), 'PIDecoder_blackscholes_2k_Pboth')

# %% [markdown]
# Prediction and plotting

# %%
with torch.no_grad():  
    device = torch.device("cuda")
    
    # lambda1 and beta1 are the parameters in the kernel function used to define the CMMD loss function
    lambda1 = torch.tensor(-0.5, requires_grad = True).to(device)
    beta1 = torch.tensor(4.0, requires_grad = True).to(device)
    lambda1 = torch.nn.Parameter(lambda1)
    beta1 = torch.nn.Parameter(beta1)
    
    #Calling the DNN class and registering lambda1 and beta1 as learnable parameters
    model = DNN().to(device)
    model.register_parameter('lanbda11',lambda1)
    model.register_parameter('beta1',beta1)
    model.load_state_dict(torch.load('PIDecoder_blackscholes_2k_Pboth'))
    model.to(device)
    
    # Prediction upto nt number of time steps
    nt =1000
    mae,prm,X_hat,X=test(model.double(),nt)
    prm = prm.cpu()
    prm = prm.detach().numpy()
    Y_at_t = X[:,260]
    print(X_hat.shape)
    Y_hat_at_t = X_hat[:,260]
# Out:
# (1500, 1000)
# (1500, 2)
# (1500, 1000)

# %%
#Plotting the prictions (Within the training window) # Training has been done till 100 time steps
x = np.linspace(0.5,1.6,300)
x1 = np.linspace(0.5,1.6,500)
from scipy.stats import gaussian_kde

# Computing pdf outside the training window
density = gaussian_kde(X[:,68])
density_1 = gaussian_kde(X_hat[:,68] )

# Computing pdf outside the training window
density_p = gaussian_kde(X[:,260])
density_p_1 = gaussian_kde(X_hat[:,260] )
plt.figure(1)
plt.plot(x,density(x),"*", color = "k",label = "Ground Truth")
plt.plot(x1,density_1(x1),"r",label = "Proposed approach")
plt.ylabel('Probability density function')
plt.xlabel('QoI') 
plt.legend()
plt.savefig('PI_BS_Pboth.pdf')

# %%
 #Plotting the prictions (Outside the training window)
plt.figure(2)
plt.plot(x,density_p(x),"*", color = "k",label = "Ground Truth")
plt.plot(x,density_p_1(x),"g",label = "Proposed approach")
plt.ylabel('Probability density function')
plt.xlabel('QoI') 
plt.legend()
plt.savefig('PI_BS_Pboth_pred.pdf')
