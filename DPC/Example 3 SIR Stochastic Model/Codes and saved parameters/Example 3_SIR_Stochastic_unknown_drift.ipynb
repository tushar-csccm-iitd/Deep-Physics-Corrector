# %%
#Import Libraries
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
import torchvision.transforms as transforms
from sklearn.metrics import mean_absolute_error as mae
mse = nn.MSELoss()
import torch.optim.lr_scheduler as lr_scheduler
device=device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import seaborn as sns
from mpl_toolkits.axes_grid1.inset_locator import (inset_axes, InsetPosition, mark_inset)
alpha = 0.01
beta = 0.5
gamma = 0.5
N = 2000

# %% [markdown]
# Euler Maruyama SDE Solver for Data Generation

# %%
def Euler_Maruyama(param,dt,n):
    [p1,p2] = param
    S = np.zeros(n)
    S[0] = p1
    I = np.zeros(n)
    I[0] = p2
    R = np.zeros(n)
    for i in range(n-1):
        S[i+1] = S[i] + dt*(-beta*S[i]*I[i])
        I[i+1] = I[i] + dt*(beta*S[i]*I[i] - gamma*I[i]) + alpha*I[i]*np.random.randn(1)*np.sqrt(dt)
        R[i+1] = N - S[i+1]-I[i+1]
    return S,I,R

# %% [markdown]
# Pure Physics(Incomplete) model using Euler Maruyama solver

# %%
def Physics_pure(param,batch_size,dt,n):
    zp = param
    s_dash = torch.zeros((batch_size,n),dtype = float).to(device) 
    s_dash[:,0] = zp[:,0]*torch.ones((batch_size), dtype = float).to(device)
    
    I_dash = torch.zeros((batch_size,n),dtype = float).to(device) 
    I_dash[:,0] = zp[:,1]*torch.ones((batch_size), dtype = float).to(device)
    
    R_dash = torch.zeros((batch_size,n),dtype = float).to(device) 
    
    dT = 0.001 * torch.ones(batch_size).to(device)
    dW = torch.sqrt(dT)*torch.randn(batch_size).to(device)
    for i in range(n-1):
        s_dash[:,i+1] = s_dash[:,i] + dT*(-beta *s_dash[:,i]*I_dash[:,i])
        I_dash[:,i+1] = I_dash[:,i] + dT + alpha*I_dash[:,i]*dW
        R_dash[:,i+1] = N - s_dash[:,i+1]-I_dash[:,i+1]
    return I_dash

# %% [markdown]
# Data Generation

# %%
#Uniform random initialization for 3500 data points
S0 = np.random.uniform(1200,1800,3500)
I0 = np.random.uniform(20,200,3500)
print(S0[2])

#Standard Deviation for S0 and I0
std_x1 = np.std(S0)
std_x2 = np.std(I0)

#Time discretization domain
t = np.linspace(0,0.1,100)
dt = t[2]-t[1]

#Initialising output matrices
X = np.zeros([3500,100])
Y = np.zeros([3500,100])
Z = np.zeros([3500,100])

#Initialising parameters matrix
prm = np.zeros([3500,2]) 

for i in range(3500):
    if i%50 == 0:
        p1 = S0[i]
        p2 = I0[i]
    param = [p1,p2]
    X[i,:],Y[i,:],Z[i,:]= Euler_Maruyama(param,dt,100)
    prm[i] = param
print(np.shape(Y))
print("prm",prm.shape)

#plot output
plt.figure(1)
plt.plot(t, Y[10,:], label='I')
plt.plot(t, Y[11,:], label='I')
plt.plot(t, Y[12,:], label='I')
txt = "x1="+str(prm[10,0])[0:7]+" x2=" + str(prm[10,1])[0:7]
plt.title(label=txt)
plt.xlabel('Time (s)')
plt.legend()
plt.grid(True)
# Out:
# 1461.9497422800725
# (3500, 100)
# prm (3500, 2)

# %%
#Pdf plot of generated data at a particular time step
Y_at_t = Y[:,33]
print(prm[0])
sns.kdeplot(Y_at_t)
# Out:
# [1318.48432715  188.57800931]
# <AxesSubplot:ylabel='Density'>

# %%
#Preparing training dataset and dataloader
train_data = torch.from_numpy(Y[0:2000,:]).to(device)
train_prm  = torch.from_numpy(prm[0:2000,:]).to(device)

Train_data = TensorDataset(train_data,train_prm)
Train_dl = DataLoader(Train_data, batch_size=50, shuffle=False)# We didn’t shuffle the data)

# %% [markdown]
# Deep Neural network for proposed model
# <br>
# S_dash : number of susceptible individuals
# <br>
# I_dash : number of infected individuals
# <br>
# R_dash : number of recovered individuals

# %%
class DNN(nn.Module):
    def __init__(self):
        super(DNN, self).__init__()
        # function for stochastic term
        self.fA1 = nn.Sequential(nn.Linear(14, 64),
                                 nn.ELU(),
                                 nn.Linear(64 ,256),
                                 nn.ELU(),
                                 nn.Linear(256,512),
                                 nn.ELU(),
                                 nn.Linear(512,512),
                                 nn.ELU(),
                                 nn.Linear(512,256),
                                 nn.ELU(),
                                 nn.Linear(256, 64),
                                 nn.ELU(),
                                 nn.Linear(64,1))


    def forward(self, batch_size, params,n):
        zp = params
        
        #Initializing the solution matrices
        S_dash = torch.zeros((batch_size,n),dtype = float).to(device)
        I_dash = torch.zeros((batch_size,n),dtype = float).to(device)
        R_dash = torch.zeros((batch_size,n),dtype = float).to(device)
        
        #As the initial condition S_dash and I_dahs(@ t=0) = S0 and I0, assigning first column of matrices = initial condition
        S_dash[:,0] = zp[:,0]*torch.ones((batch_size), dtype = float).to(device)
        I_dash[:,0] = zp[:,1]*torch.ones((batch_size), dtype = float).to(device)
         
        #Loop for time marching    
        for i in range(n-1):
            S = torch.reshape(S_dash[:,i],(batch_size,1))
            I = torch.reshape(I_dash[:,i],(batch_size,1))
            
            # Taking sample for Z(random variable) from standard gaussian distribution
            z_A1 = torch.randn(batch_size,10).to(device)
            
            #Taking out 1st column out from the parameters i.e S0 and calling it z_p0
            z_p0 = torch.reshape(zp[:,0],(batch_size,1))
            
            #Taking out 2nd column out from the parameters i.e I0 and calling it z_p1
            z_p1 = torch.reshape(zp[:,1],(batch_size,1))
            
            #Input to the Neural network that will fill in for the unknown part
            input_fA1 = torch.cat((z_A1,I,S,z_p0,z_p1),1).to(device)
            
            # Outputs from the neural networks
            fA1_loc = self.fA1(input_fA1)
            
            #Resize
            fA1_loc_ = torch.squeeze(fA1_loc)
            
            # Time as tensor  of size = batch size
            dT = dt * torch.ones(batch_size).to(device)
            
            # White noise as tensor of size = batch size
            dW = torch.sqrt(dT)*torch.randn(batch_size).to(device)
            
            # Using explicit Euler Maruyama to compute the output at (i+1)th step given the ith step output(I_dash)
            S_dash[:,i+1] = S_dash[:,i] + dT*(-beta*S_dash[:,i].clone()*I_dash[:,i].clone())
            #I_dash[:,i+1] = I_dash[:,i] + dt*(zp[:,0]*S_dash[:,i]*I_dash[:,i] - zp[:,1]*I_dash[:,i]) + alpha*I_dash[:,i]*dW
            I_dash[:,i+1] = I_dash[:,i] + dT*(fA1_loc_) - dT*(gamma*I_dash[:,i]) + alpha*I_dash[:,i]*dW
            R_dash[:,i+1] = N - S_dash[:,i+1]-I_dash[:,i+1]
          
        s_hat = I_dash
        
        return s_hat, zp

# %% [markdown]
# Neural Network for purely data driven solver

# %%
class Datadriven(nn.Module):
    def __init__(self):
        super(Datadriven,self).__init__()
        self.network1 = nn.Sequential(nn.Linear(13, 64),
                                 nn.ELU(),
                                 nn.Linear(64 ,256),
                                 nn.ELU(),
                                 nn.Linear(256,512),
                                 nn.ELU(),
                                 nn.Linear(512,256),
                                 nn.ELU(),
                                 nn.Linear(256, 64),
                                 nn.ELU(),
                                 nn.Linear(64,1))
    
    def forward(self, batch_size, params,time):
        Z = torch.randn(batch_size,10).to(device)
        network_input = torch.cat((params,Z,time),1).to(device)
        output  = self.network1(network_input)
        out = torch.squeeze(output)
        return out

# %% [markdown]
# CMMD Loss Function

# %%
def gram_matrix(x, y, gamma1, pi1):
    sq_dist = torch.sum((torch.unsqueeze(x, 1)-torch.unsqueeze(y, 0))**2,2)      
    kernel = (pi1*torch.exp(-gamma1*sq_dist))
    return  kernel

# %%
def multidot(A,B,C,D):

  return torch.tensordot(A,torch.tensordot(B,torch.tensordot(C,D,dims=1),dims=1),dims=1)

# %%
def CMMD_loss(x_comp, x_hat, params, zp):
        
        gamma1 = torch.sigmoid(lambda1)
        #Mixture Coefficients   
        pi1 = torch.exp(beta1).to(device)
        #Gram Matrices
        k_d = gram_matrix(params, params, gamma1, pi1)
        #print('k_d',k_d.shape)
        k_s = gram_matrix(zp, zp, gamma1, pi1)
        #print('k_s',k_s)
        l_d = gram_matrix(x_comp, x_comp, gamma1, pi1)
        #print('l_d',l_d)
        l_s = gram_matrix(x_hat, x_hat, gamma1, pi1)
        #print('l_s',l_s)
        k_sd = gram_matrix(params,zp, gamma1, pi1)
        #print('k_sd',k_sd)
        l_ds = gram_matrix(x_comp, x_hat, gamma1, pi1)
        #print('l_ds',l_ds)
        lam = 2.0 #hyperparameteR
        row, col = k_d.shape
        k_d_tilda = k_d + (lam*torch.eye(row,col,device="cuda"))
        #print( 'k_d_tild',k_d_tilda)
        k_s_tilda = k_s + (lam*torch.eye(row,col,device="cuda"))
        #print(' k_s_tilda',k_s_tilda)
        k_sd_tilda = k_sd + (lam*torch.eye(row,col,device="cuda"))
        #print('k_sd_tilda',k_sd_tilda)
        loss = torch.sqrt(torch.trace(multidot(k_d,torch.inverse(k_d_tilda),l_d,torch.inverse(k_d_tilda))) + torch.trace(multidot(k_s,torch.inverse(k_s_tilda),l_s,torch.inverse(k_s_tilda))) - 2*torch.trace(multidot(k_sd,torch.inverse(k_d_tilda),l_ds,torch.inverse(k_s_tilda))))
        #print('shape',loss.shape)
        return loss

# %% [markdown]
# Training function for the proposed model

# %%
def train_CMMD(model_dpc, epochs):
    opt = torch.optim.Adam(model_dpc.parameters(),lr = .0000001)
    train_loss_epochs = torch.empty((epochs)).to(device)
    scheduler = lr_scheduler.StepLR(opt, step_size = 50, gamma=0.9, verbose = True)
    for epoch in range(epochs):
        print(epoch)
        a=1
        b=1
        c=10
        i=0
        train_cum_loss = 0
        for batch,params in Train_dl:
            s = batch
            params = params[:,0:2]
            #print("params",params.shape)
            batch_size = s.shape[0]
            x1 = params[:,0] # since params is taking new set of values every iterations 
            #print("omega",omega.shape)
            x2 =  params[:,1]
            opt.zero_grad()
            s_hat,zp = model_dpc(batch_size=batch_size, params = params, n=100)
            i=+1
            loss_CMMD = CMMD_loss(s, s_hat, params, params)
            loss_rec = ((s - s_hat)**2).sum()
            loss = a*loss_CMMD + loss_rec
            train_cum_loss+=loss
            loss.backward()
            opt.step()
        scheduler.step()
        train_loss_epochs[epoch] = train_cum_loss/2000 ########bATCH_SIZE
        print("loss_CMMD",loss_CMMD)
        print("loss_rec",loss_rec)
    return model_dpc, train_loss_epochs,opt

# %% [markdown]
# Test function for the proposed DPC model

# %%
def test(model_dpc,n):
    S0 = np.random.uniform(1200,1800,1500)
    I0 = np.random.uniform(20,200,1500)
    t = np.linspace(0,0.1,100)
    dt = t[2]-t[1]
    X1  = np.zeros([1500,n])
    Y1  = np.zeros([1500,n])
    Z1 = np.zeros([1500,n])
    prm_test = np.zeros([1500,2]) 
    for i in range(1500):
        p1 = S0[i]
        p2 = I0[i]
        param = [p1,p2]
        X1[i,:],Y1[i,:],Z1[i,:]= Euler_Maruyama(param,dt,n)
        prm_test[i] = param
    print(Y1.shape)
    print(prm_test.shape)
    test_data1 = torch.from_numpy(Y1).to(device) 
    test_prm1 = torch.from_numpy(prm_test).to(device)
    Test_data1 = TensorDataset(test_data1,test_prm1)
    Test_dl_1 = DataLoader(Test_data1, batch_size=50, shuffle=False)
    with torch.no_grad():  
        s_full =  torch.empty(1500,n)
        s_hat_full =  torch.empty(1500,n)
        parameters =  torch.empty(1500,2) 
        i=0
    for batch,p in Test_dl_1:
        s = batch
        #print("s_shape",s.shape)
        batch_size = s.shape[0]
        parameters[i*batch_size:(i+1)*batch_size,:] = p
        #print(batch_size)
        s_full[i*batch_size:(i+1)*batch_size,:] = s
        s_hat,zp = model_dpc(batch_size=batch_size, params = p, n=n)
        s_hat_full[i*batch_size:(i+1)*batch_size,:] = s_hat
        i+=1
    x_hat = s_hat_full.cpu()
    X_hat = x_hat.detach().numpy()
    x = s_full.cpu()
    X= x.detach().numpy()
    er = mae = np.absolute(np.subtract(X_hat, X)).mean() 

    return er,parameters,X_hat,X

# %% [markdown]
# Test function for the all the models combined i.e the DPC model, pure physics and pure data driven model

# %%
def test1(model_dpc, model, n):
    S0 = np.random.uniform(1200,1800,1500)
    I0 = np.random.uniform(20,200,1500)
    t = np.linspace(0,0.1,100)
    dt = t[2]-t[1]
    X1  = np.zeros([1500,n])
    Y1  = np.zeros([1500,n])
    Z1 = np.zeros([1500,n])
    prm_test = np.zeros([1500,2]) 
    for i in range(1500):
        p1 = S0[i]
        p2 = I0[i]
        param = [p1,p2]
        X1[i,:],Y1[i,:],Z1[i,:]= Euler_Maruyama(param,dt,n)
        prm_test[i] = param
    print(Y1.shape)
    print(prm_test.shape)
    test_data1 = torch.from_numpy(Y1).to(device) 
    test_prm1 = torch.from_numpy(prm_test).to(device)
    Test_data1 = TensorDataset(test_data1,test_prm1)
    Test_dl_1 = DataLoader(Test_data1, batch_size=1500, shuffle=False)
    with torch.no_grad():  
        s_full =  torch.empty(1500,n)
        s_hat_full =  torch.empty(1500,n)
        s_hat_full_data = torch.empty(1500,n)
        s_hat_full_physics = torch.empty(1500,n)
        parameters =  torch.empty(1500,2) 
        i=0
    for batch,p in Test_dl_1:
        s = batch
        #print("s_shape",s.shape)
        batch_size = s.shape[0]
        parameters[i*batch_size:(i+1)*batch_size,:] = p
        #print(batch_size)
        s_full[i*batch_size:(i+1)*batch_size,:] = s
        s_hat,zp = model_dpc(batch_size=batch_size, params = p, n=n)
        for t in range(n):
            time = t*dt*torch.ones((batch_size,1), dtype = float).to(device)
            s_hat_full_data[:,t] = model(batch_size=batch_size, params = p, time = time)   
        s_hat_full[i*batch_size:(i+1)*batch_size,:] = s_hat
        s_hat_full_physics = Physics_pure(p,batch_size, dt, n) 
        i+=1
    x_hat = s_hat_full.cpu()
    X_hat = x_hat.detach().numpy()
    x_hat_data = s_hat_full_data.cpu()
    X_hat_data = x_hat_data.detach().numpy()
    x_hat_physics = s_hat_full_physics.cpu()
    X_hat_physics = x_hat_physics.detach().numpy()
    x = s_full.cpu()
    X= x.detach().numpy()
    er = mae = np.absolute(np.subtract(X_hat, X)).mean() 

    return er, parameters, X_hat, X_hat_data, X_hat_physics, X

# %% [markdown]
# Main: Training of the proposed model till convergence is reached

# %%
# No of epochs for training
epochs = 750

# lambda1 and beta1 are the parameters in the kernel function used to define the CMMD loss funct
lambda1 = torch.tensor(-0.5, requires_grad = True).to(device)
beta1 = torch.tensor(4.0, requires_grad = True).to(device)

#Included in the training process
lambda1 = torch.nn.Parameter(lambda1)
beta1 = torch.nn.Parameter(beta1)
model_dpc = DNN().to(device)
model_dpc.register_parameter('lanbda11',lambda1)
model_dpc.register_parameter('beta1',beta1)

#Training
model_dpc,train_loss_epochs,opt= train_CMMD(model_dpc.double(),epochs)

#plotting training loss vs number of epochs at the end of the training
epochs_array = np.linspace(0,epochs,epochs)
train_loss_epochs= train_loss_epochs.cpu()
train_loss_epochs= train_loss_epochs.detach().numpy()
fig1=plt.figure(1)
plt.plot(epochs_array ,train_loss_epochs, label="training_loss")
plt.xlabel("Epochs")
plt.ylabel("Training loss")
# Out:
# Adjusting learning rate of group 0 to 1.0000e-05.
# 0
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1251959.8645, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 1
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1244390.6307, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 2
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1240214.4570, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 3
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1265682.4709, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 4
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1316841.2119, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 5
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1311549.4263, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 6
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1250490.7253, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 7
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1270086.6255, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 8
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1252057.6558, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 9
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1257540.9970, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 10
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1247336.6395, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 11
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1257424.7652, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 12
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1036815.1342, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 13
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1033771.0722, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 14
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1021089.9382, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 15
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(993085.3798, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 16
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1025583.9461, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 17
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1003460.3937, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 18
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(984702.2452, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 19
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1015192.4326, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 20
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1010291.3665, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 21
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1051053.5823, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 22
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1052361.0741, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 23
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1004769.4685, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 24
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(995786.4126, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 25
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1030863.8473, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 26
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1292395.1903, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 27
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1363392.3548, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 28
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1501353.8680, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 29
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1494664.3683, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 30
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1455536.1568, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 31
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1505162.9055, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 32
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1441749.1107, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 33
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1459227.7323, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 34
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1455026.1089, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 35
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1400533.2697, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 36
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1488926.6741, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 37
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1473801.8941, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 38
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1428340.3886, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 39
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1435957.1713, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 40
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1404480.1996, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 41
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1416037.7247, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 42
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1402728.9597, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 43
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1389540.4274, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 44
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1255638.1711, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 45
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1170682.7907, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 46
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1211598.8636, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 47
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1191422.1330, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 48
# Adjusting learning rate of group 0 to 1.0000e-05.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1181076.3864, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 49
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1282235.3717, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 50
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1263076.7348, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 51
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1259796.0226, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 52
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1263224.7546, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 53
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1257018.0140, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 54
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1260646.6534, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 55
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1245189.3512, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 56
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1258123.1441, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 57
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1253660.0005, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 58
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1237918.8330, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 59
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1230299.4928, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 60
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1076472.5565, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 61
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1070800.4232, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 62
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1064656.7740, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 63
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1088488.1735, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 64
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1096287.7423, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 65
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1121087.9230, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 66
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(991992.1928, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 67
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1010652.6066, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 68
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1346052.0462, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 69
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1464609.8733, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 70
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1476331.6560, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 71
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1458074.3663, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 72
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1484523.5924, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 73
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1466660.6893, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 74
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1465618.4519, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 75
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1450422.6859, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 76
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1453001.3920, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 77
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1457653.7636, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 78
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1408710.9685, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 79
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1623272.6624, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 80
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1474352.3688, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 81
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1448368.0878, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 82
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1385634.8226, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 83
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1376024.6840, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 84
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1391351.4646, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 85
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1385189.1213, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 86
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1381740.4736, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 87
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1382933.0863, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 88
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1409009.6239, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 89
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1380719.3975, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 90
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1384047.1598, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 91
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1358676.5400, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 92
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1398035.3652, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 93
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1363578.4090, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 94
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1380961.7031, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 95
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1321975.5847, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 96
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1333489.8213, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 97
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1213938.3303, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 98
# Adjusting learning rate of group 0 to 9.0000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1159599.2804, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 99
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1145448.5833, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 100
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1140698.6625, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 101
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1158886.0065, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 102
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1154495.7318, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 103
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1145325.1430, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 104
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1148457.7007, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 105
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1038518.9871, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 106
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1037822.6960, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 107
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1040429.9887, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 108
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1019359.3867, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 109
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1023356.3635, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 110
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1007319.7879, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 111
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1032916.4374, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 112
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1007540.3803, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 113
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1036405.9546, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 114
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1018494.1724, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 115
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1001203.4162, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 116
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(991957.8866, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 117
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(976444.4276, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 118
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(988836.9572, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 119
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(943541.2172, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 120
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(995120.7199, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 121
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(953738.9401, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 122
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(971554.6962, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 123
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1026712.5520, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 124
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1026797.8046, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 125
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1041071.7536, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 126
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1024907.7868, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 127
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1066102.8197, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 128
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1070442.7398, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 129
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1076435.2864, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 130
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1026050.2618, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 131
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(994553.7589, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 132
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1021709.8845, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 133
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1046467.5279, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 134
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(993655.6999, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 135
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1013523.1041, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 136
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1020784.4140, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 137
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1019828.0819, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 138
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1037605.4378, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 139
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1014562.3070, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 140
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1026598.3144, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 141
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1066408.2922, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 142
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1041652.6022, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 143
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1080859.6804, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 144
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1061755.8451, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 145
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1011656.0816, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 146
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(984621.1794, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 147
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(982418.5210, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 148
# Adjusting learning rate of group 0 to 8.1000e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1088789.3710, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 149
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(978744.6241, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 150
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(998321.7461, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 151
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1059916.7573, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 152
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1048417.2162, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 153
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1035450.7958, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 154
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1087503.9312, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 155
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1096046.2194, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 156
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1044266.8805, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 157
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1038322.2756, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 158
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1108334.6583, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 159
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1027347.3811, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 160
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1062571.8862, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 161
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(984368.7324, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 162
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1040979.0628, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 163
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1049011.6273, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 164
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1095163.5499, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 165
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1055722.3161, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 166
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1074614.9249, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 167
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1050930.9112, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 168
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1013836.4399, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 169
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1063382.8073, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 170
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1008450.1293, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 171
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1081662.2402, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 172
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1098410.8553, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 173
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1101453.4449, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 174
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1098803.9437, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 175
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1029146.6143, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 176
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1090152.2413, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 177
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1059703.5194, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 178
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1022310.9225, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 179
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1066152.9865, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 180
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1090689.2313, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 181
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1105598.2418, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 182
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1070996.8554, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 183
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1050753.6477, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 184
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1000555.7298, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 185
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1096912.5098, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 186
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1115926.7715, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 187
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1020547.5198, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 188
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1044776.8611, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 189
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1129104.9251, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 190
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1077458.2742, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 191
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1054581.8398, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 192
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1033142.3620, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 193
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1003630.3787, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 194
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1042661.2802, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 195
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1112143.4636, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 196
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1107725.7356, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 197
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1055927.7908, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 198
# Adjusting learning rate of group 0 to 7.2900e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1072640.7074, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 199
# Adjusting learning rate of group 0 to 6.5610e-06.
# loss_CMMD tensor(0.1998, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward>)
# loss_rec tensor(1147612.2020, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# Text(0, 0.5, 'Training loss')

# %%
torch.save(autoencoder.state_dict(), 'PIDecoder_SIR_SDE_2k_Pdrift1')

# %%
with torch.no_grad():  
    device = torch.device("cuda")
    lambda1 = torch.tensor(-0.5, requires_grad = True).to(device)
    beta1 = torch.tensor(4.0, requires_grad = True).to(device)
    lambda1 = torch.nn.Parameter(lambda1)
    beta1 = torch.nn.Parameter(beta1)
    model_dpc = DNN().to(device)
    model_dpc.register_parameter('lanbda11',lambda1)
    model_dpc.register_parameter('beta1',beta1)
    model_dpc.load_state_dict(torch.load('PIDecoder_SIR_SDE_2k_Pdrift1'))
    model_dpc.to(device)
    model = Datadriven().to(device)
    model.register_parameter('lanbda11',lambda1)
    model.register_parameter('beta1',beta1) 
    model.load_state_dict(torch.load('PIDecoder_SIR_SDE_2k_Pdiffusion_data'))
    
    nt =200
    mae,prm, X_hat, X_hat_data, X_hat_physics, X=test1(model_dpc.double(), model.double(), n=nt) 
    prm = prm.cpu()
    prm = prm.detach().numpy()
   
    from scipy.stats import gaussian_kde
    density = gaussian_kde(X[:,10])
    density_1 = gaussian_kde(X_hat[:,10] )
    density_2 = gaussian_kde( X_hat_data[:,10])
    density_3 = gaussian_kde(X_hat_physics[:,10])
    
    density_p = gaussian_kde(X[:,130])
    density_p_1 = gaussian_kde(X_hat[:,130] )
    density_p_2 = gaussian_kde( X_hat_data[:,130])
    density_p_3 = gaussian_kde(X_hat_physics[:,130])
    
  
    xs = np.linspace(-50,2100,100)
    ys = np.linspace(-50,2100,20)
    zs = np.linspace(-50,2100,150)
    p = np.linspace(-20,250,200)  
    
    plt.figure(1)
    fig1, ax1 = plt.subplots()
    ax1.plot(zs,density(zs),"*",color ="k", label = "Ground Truth")
    ax1.plot(xs,density_1(xs),"r", label = "Proposed approach")
    ax1.plot(ys,density_2(ys),"-^",color ="m",label = "Data only")
    ax1.plot(p,density_3(p),"-v",label = " Incomplete physics only")
    ax1.set_ylabel('Probability density function')
    ax1.set_xlabel('QoI')
    ax1_in = ax1.inset_axes([.255,.36, 0.30, 0.30]) 
    ax1.legend()
    x = np.linspace(-50,-20)
    density_33 = gaussian_kde(X_hat_data[:,30])
    ax1_in.plot(x,density_33(x),"-^", color = "m")
    plt.savefig('multi_PI_SIR_SDE_PDrift1.pdf')
# Out:
# (1500, 200)
# (1500, 2)

# %%
fig2, ax2 = plt.subplots()
q = np.linspace(-35,350,150)
p = np.linspace(-21,2100,350)
ax2.plot(zs,density_p(zs),"*",color ="k", label = "Ground Truth")
ax2.plot(xs,density_p_1(xs),"g", label = "Proposed approach")
ax2.plot(ys,density_p_2(ys),"-^",color ="m",label = "Data only")
ax2.plot(q,density_p_3(q),"-v",label = "Incomplete physics only")
ax2.set_ylabel('Probability density function')
ax2.set_xlabel('QoI')
ax2_in = ax2.inset_axes([.27,.36, 0.30, 0.30]) 
ax2.legend()
x = np.linspace(-50,-20)
density_p_33 = gaussian_kde(X_hat_data[:,130])
ax2_in.plot(x,density_p_33(x),"-^", color ="m")
plt.savefig('multi_PI_SIR_SDE_PDrift_pred1.pdf')

# %% [markdown]
# Hellinger distance

# %%
def Hellinger(pdf1,pdf2):
    output =np.sum(np.power(np.sqrt(pdf1)-np.sqrt(pdf2),2))
    return output

# %%
from scipy.stats import gaussian_kde
with torch.no_grad():  
    device = torch.device("cuda")
    lambda1 = torch.tensor(-0.5, requires_grad = True).to(device)
    beta1 = torch.tensor(4.0, requires_grad = True).to(device)
    lambda1 = torch.nn.Parameter(lambda1)
    beta1 = torch.nn.Parameter(beta1)
    model_dpc = DNN().to(device)
    model_dpc.register_parameter('lanbda11',lambda1)
    model_dpc.register_parameter('beta1',beta1)
    model_dpc.load_state_dict(torch.load('PIDecoder_SIR_SDE_2k_Pdrift1'))
    model_dpc.to(device)
    model = Datadriven().to(device)
    model.register_parameter('lanbda11',lambda1)
    model.register_parameter('beta1',beta1) 
    model.load_state_dict(torch.load('PIDecoder_SIR_SDE_2k_Pdiffusion_data'))
    
    nt =200
    x = np.linspace(750,2250,350)
    y = np.linspace(750,2250,350)
    z = np.linspace(750,2250,350)
    p = np.linspace(750,2250,350)
    er_dpc=np.zeros([nt])
    er_pd=np.zeros([nt])
    er_pp=np.zeros([nt])
    mae,prm, X_hat, X_hat_data, X_hat_physics, X=test1(model_dpc.double(), model.double(), n=nt)
    for i in range(1,nt):
        density = gaussian_kde(X[:,i])
        density_DPC = gaussian_kde(X_hat[:,i])
        density_PD = gaussian_kde(X_hat_data[:,i])
        density_PP = gaussian_kde(X_hat_physics[:,i])
        er_dpc[i] = Hellinger(density(x),density_DPC(y))
        er_pd[i] = Hellinger(density(x),density_PD(z))
        er_pp[i] = Hellinger(density(x),density_PP(p))
    
    er_dpc_mean = np.mean(er_dpc)
    er_pd_mean = np.mean(er_pd)
    er_pp_mean = np.mean(er_pp)
    print(er_dpc_mean)
    print(er_pd_mean)
    print(er_pp_mean)
# Out:
# (1500, 200)
# (1500, 2)
# 0.004815984798255791
# 0.2273974656482529
# 0.2273974656482529

# %%
er_dpc_mean = np.zeros(5)
er_pd_mean = np.zeros(5)
er_pp_mean= np.zeros(5)
for k in range(5):
    from scipy.stats import gaussian_kde
    with torch.no_grad():  
        device = torch.device("cuda")
        lambda1 = torch.tensor(-0.5, requires_grad = True).to(device)
        beta1 = torch.tensor(4.0, requires_grad = True).to(device)
        lambda1 = torch.nn.Parameter(lambda1)
        beta1 = torch.nn.Parameter(beta1)
        model_dpc = DNN().to(device)
        model_dpc.register_parameter('lanbda11',lambda1)
        model_dpc.register_parameter('beta1',beta1)
        model_dpc.load_state_dict(torch.load('PIDecoder_SIR_SDE_2k_Pdrift1'))
        model_dpc.to(device)
        model = Datadriven().to(device)
        model.register_parameter('lanbda11',lambda1)
        model.register_parameter('beta1',beta1) 
        model.load_state_dict(torch.load('PIDecoder_SIR_SDE_2k_Pdiffusion_data'))

        nt =200
        x = np.linspace(750,2250,350)
        y = np.linspace(750,2250,350)
        z = np.linspace(750,2250,350)
        p = np.linspace(750,2250,350)
        er_dpc=np.zeros([nt])
        er_pd=np.zeros([nt])
        er_pp=np.zeros([nt])
        mae,prm, X_hat, X_hat_data, X_hat_physics, X=test1(model_dpc.double(), model.double(), n=nt)
        for i in range(1,nt):
            density = gaussian_kde(X[:,i])
            density_DPC = gaussian_kde(X_hat[:,i])
            density_PD = gaussian_kde(X_hat_data[:,i])
            density_PP = gaussian_kde(X_hat_physics[:,i])
            er_dpc[i] = Hellinger(density(x),density_DPC(y))
            er_pd[i] = Hellinger(density(x),density_PD(z))
            er_pp[i] = Hellinger(density(x),density_PP(p))

        er_dpc_mean[k] = np.mean(er_dpc)
        er_pd_mean[k] = np.mean(er_pd)
        er_pp_mean[k] = np.mean(er_pp)
        print("dpc",er_dpc_mean)
        print("pd",er_pd_mean)
        print("pp",er_pp_mean)
Error_dpc =  np.mean(er_dpc_mean)
Error_pd =  np.mean(er_pd_mean)
Error_pp =  np.mean(er_pp_mean)

print("Error_dpc",Error_dpc)
print("Error_dpc",Error_pd)
print("Error_dpc",Error_pp)
# Out:
# (1500, 200)
# (1500, 2)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9300/2458456913.py in <module>
#      34             density_PD = gaussian_kde(X_hat_data[:,i])
#      35             density_PP = gaussian_kde(X_hat_physics[:,i])
# ---> 36             er_dpc[i] = Hellinger(density(x),density_DPC(y))
#      37             er_pd[i] = Hellinger(density(x),density_PD(z))
#      38             er_pp[i] = Hellinger(density(x),density_PP(p))
#
# NameError: name 'Hellinger' is not defined
