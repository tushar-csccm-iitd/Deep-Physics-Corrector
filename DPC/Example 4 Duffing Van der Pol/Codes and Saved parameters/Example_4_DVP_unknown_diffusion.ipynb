# %%
#Import Libraries
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
import torchvision.transforms as transforms
from sklearn.metrics import mean_absolute_error as mae
mse = nn.MSELoss()
import torch.optim.lr_scheduler as lr_scheduler
device=device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import seaborn as sns
x_in = 1
x_dot_in = 0.25
alpha = 100
sigma =1000
from scipy.integrate import solve_ivp
import math
# rnd = np.random.default_rng(0)

# %% [markdown]
# Euler Maruyama SDE Solver for Data Generation

# %%
def Euler_Maruyama(param,dt,n):
    [p1,p2] = param
    sol = np.zeros(n)
    sol_dot =  np.zeros(n) 
    sol[0] =x_in 
    sol_dot[0] = x_dot_in
    for i in range(n-1):
        sol[i+1] = sol[i] + sol_dot[i]*dt
        sol_dot[i+1] = sol_dot[i] + dt*(-(p1*sol_dot[i]*(1-sol[i]**2)) + p2*sol[i] - alpha*sol[i]**3 + sigma*sol[i]*np.random.randn(1)*np.sqrt(dt))
    return sol,sol_dot

# %% [markdown]
# Pure Physics(Incomplete) model using Euler Maruyama solver

# %%
def Physics_pure(param,batch_size,dt,n):
    zp = param
    s_dash = torch.zeros((batch_size,n),dtype = float).to(device) 
    s_dash_dot = torch.zeros((batch_size,n),dtype = float).to(device)
    s_dash[:,0] = x_in * torch.ones((batch_size), dtype = float).to(device)
    s_dash_dot[:,0] = x_dot_in * torch.ones((batch_size), dtype = float).to(device)
    dT = 0.001 * torch.ones(batch_size).to(device)
    dW = torch.sqrt(dT)*torch.randn(batch_size).to(device)
    for i in range(n-1):
        s_dash[:,i+1] = s_dash[:,i] + dT*s_dash_dot[:,i]
        s_dash_dot[:,i+1] = s_dash_dot[:,i] + dT*(-(zp[:,0]*s_dash_dot[:,i]) + zp[:,1]*s_dash[:,i] - alpha*s_dash[:,i]**3 + sigma*s_dash[:,i]*dW)
    return s_dash, s_dash_dot

# %% [markdown]
# Data Generation

# %%
#Uniform random initialization for 3500 data points
ns = 3500
t0 = 0
tn = 1
ts = (tn-t0)*1000

#Uniform random initialization for ns data points
c=np.random.uniform(0.1,.5,ns)
k=np.random.uniform(5,50,ns)
print(c[2])

#Standard Deviation for c and k
std_c = np.std(c)
std_k = np.std(k)

#Time discretization domain
t = np.linspace(t0,tn,ts)
dt = t[2]-t[1]

#Initialising output matrices
X = np.zeros([ns,ts])
X_dot = np.zeros([ns,ts])

#Initialising parameters matrix
prm =np.zeros([ns,2]) 
for i in range(ns):
    #z=np.random.randn(100)
    if i%50 == 0:
        p1 = c[i]
        p2 = k[i]
    param = [p1,p2]
    X[i,:],X_dot[i,:] = Euler_Maruyama(param,dt,ts)
    prm[i] = param
print(X.shape)
print("prm",prm.shape)

#plot output
plt.figure(1)
plt.plot(t, X[1,:], label='x')
plt.plot(t, X[2,:], label='x')
plt.plot(t, X[3,:], label='x')
plt.plot(t, X[4,:], label='x')
plt.plot(t, X[5,:], label='x')
#plt.plot(t, X_dot[10,:], label='x_dot')
txt = "x1="+str(prm[5,0])[0:7]+" x2=" + str(prm[5,1])[0:7]
plt.title(label=txt)
plt.xlabel('Time (s)')
plt.legend()
plt.grid(True)
# Out:
# 0.1373436495648932
# (3500, 1000)
# prm (3500, 2)

# %%
#Pdf plot of generated data at a particular time step
Y_at_t = X[:,5]
print(prm[0])
sns.kdeplot(Y_at_t)
# Out:
# [ 0.2073667  12.81024251]
# <AxesSubplot:ylabel='Density'>

# %%
#Preparing training dataset and dataloader
train_data = torch.from_numpy(X[0:2000,:]).to(device)
train_prm  = torch.from_numpy(prm[0:2000,:]).to(device)

Train_data = TensorDataset(train_data,train_prm)
Train_dl = DataLoader(Train_data, batch_size=50, shuffle=False)# We didn’t shuffle the data

# %% [markdown]
#  Deep Neural network for proposed model

# %%
class DNN(nn.Module):
    def __init__(self):
        super(DNN, self).__init__()
        # Neural network not being used(Not to delete it, else it will show error while loading the trained model parameters)
        self.fp1 = nn.Sequential(nn.Linear(2,256),
                                nn.ELU(),
                                nn.Linear(256,256),
                                nn.ELU(),
                                nn.Linear(256,1))
        # Neural network that will fill in for diffusion term
        self.fA1 = nn.Sequential(nn.Linear(14, 64),
                                 nn.ELU(),
                                 nn.Linear(64 ,256),
                                 nn.ELU(),
                                 nn.Linear(256,512),
                                 nn.ELU(),
                                 nn.Linear(512,512),
                                 nn.ELU(),
                                 nn.Linear(512,256),
                                 nn.ELU(),
                                 nn.Linear(256, 64),
                                 nn.ELU(),
                                 nn.Linear(64,1))


    def forward(self, batch_size, params,n):
        
        zp = params
        #Initializing the solution matrix and setting initial condition for displacement and velocity
        s_dash = torch.zeros((batch_size,n),dtype = float).to(device) 
        s_dash[:,0] = x_in*torch.ones(batch_size).to(device)
        s_dash_dot = torch.zeros((batch_size,n),dtype = float).to(device) 
        s_dash_dot[:,0] = x_dot_in*torch.ones(batch_size).to(device)
        
        #Loop for time marching
        for i in range(n-1):
            s = torch.reshape(s_dash[:,i],(batch_size,1))
            s_dot = torch.reshape(s_dash_dot[:,i],(batch_size,1))
            
            # Taking sample for Z(random variable) from standard gaussian distribution
            z_A1 = torch.randn(batch_size,10).to(device)
            
            #Taking out 1st column out from the parameters i.e p1 and calling it z_p0
            z_p0 = torch.reshape(zp[:,0],(batch_size,1))
            
            #Taking out 2nd column out from the parameters i.e p2 and calling it z_p1
            z_p1 = torch.reshape(zp[:,1],(batch_size,1))
            
            #Input to the Neural network that will fill in for the unknown part
            input_fA1 = torch.cat((z_A1,z_p0,z_p1,s,s_dot),1).to(device)
            
            # Outputs from the neural networks
            fA1_loc = self.fA1(input_fA1)
            
             #Resize
            z_p1_ = torch.squeeze(z_p1)
            z_p0_ = torch.squeeze(z_p0)
            fA1_loc_ = torch.squeeze(fA1_loc)
            
            # Time as tensor  of size = batch size
            dT = dt * torch.ones(batch_size).to(device)
            
            # White noise as tensor of size = batch size
            dW =torch.sqrt(dT)* torch.randn(batch_size).to(device)
            
            # Using explicit Euler Maruyama to compute the output at (i+1)th step given the ith step output
            s_dash[:,i+1] = s_dash[:,i] + dT*s_dash_dot[:,i]
            s_dash_dot[:,i+1] = s_dash_dot[:,i] + dT*(-z_p0_*s_dash_dot[:,i]*(1-(s_dash[:,i].clone())**2) + z_p1_*s_dash[:,i]- alpha*(s_dash[:,i].clone())**3)  + dW* fA1_loc_
        
        s_hat =  s_dash
        s_hat_dot = s_dash_dot
        return s_hat, s_hat_dot, zp

# %% [markdown]
# Neural Network for purely data driven solver

# %%
class Datadriven(nn.Module):
    def __init__(self):
        super(Datadriven,self).__init__()
        self.network1 = nn.Sequential(nn.Linear(13, 64),
                                 nn.ELU(),
                                 nn.Linear(64 ,256),
                                 nn.ELU(),
                                 nn.Linear(256,512),
                                 nn.ELU(),
                                 nn.Linear(512,256),
                                 nn.ELU(),
                                 nn.Linear(256, 64),
                                 nn.ELU(),
                                 nn.Linear(64,1))
    
    def forward(self, batch_size, params,time):
        Z = torch.randn(batch_size,10).to(device)
        network_input = torch.cat((params,Z,time),1).to(device)
        output  = self.network1(network_input)
        out = torch.squeeze(output)
        return out

# %% [markdown]
# CMMD Loss Function

# %%
def gram_matrix(x, y, gamma1, pi1):
    sq_dist = torch.sum((torch.unsqueeze(x, 1)-torch.unsqueeze(y, 0))**2,2)      
    kernel = (pi1*torch.exp(-gamma1*sq_dist))
    return  kernel

# %%
def multidot(A,B,C,D):

  return torch.tensordot(A,torch.tensordot(B,torch.tensordot(C,D,dims=1),dims=1),dims=1)

# %%
def CMMD_loss(x_comp, x_hat, params, zp):
        gamma1 = torch.sigmoid(lambda1)
        #Mixture Coefficients   
        pi1 = torch.exp(beta1).to(device)
        #Gram Matrices
        k_d = gram_matrix(params, params, gamma1, pi1)
        #print('k_d',k_d.shape)
        k_s = gram_matrix(zp, zp, gamma1, pi1)
        #print('k_s',k_s)
        l_d = gram_matrix(x_comp, x_comp, gamma1, pi1)
        #print('l_d',l_d)
        l_s = gram_matrix(x_hat, x_hat, gamma1, pi1)
        #print('l_s',l_s)
        k_sd = gram_matrix(params,zp, gamma1, pi1)
        #print('k_sd',k_sd)
        l_ds = gram_matrix(x_comp, x_hat, gamma1, pi1)
        #print('l_ds',l_ds)
        lam = 2.0 #hyperparameteR
        row, col = k_d.shape
        k_d_tilda = k_d + (lam*torch.eye(row,col,device="cuda"))
        #print( 'k_d_tild',k_d_tilda)
        k_s_tilda = k_s + (lam*torch.eye(row,col,device="cuda"))
        #print(' k_s_tilda',k_s_tilda)
        k_sd_tilda = k_sd + (lam*torch.eye(row,col,device="cuda"))
        #print('k_sd_tilda',k_sd_tilda)
        loss = torch.sqrt(torch.trace(multidot(k_d,torch.inverse(k_d_tilda),l_d,torch.inverse(k_d_tilda))) + torch.trace(multidot(k_s,torch.inverse(k_s_tilda),l_s,torch.inverse(k_s_tilda))) - 2*torch.trace(multidot(k_sd,torch.inverse(k_d_tilda),l_ds,torch.inverse(k_s_tilda))))
        #print('shape',loss.shape)
        return loss

# %% [markdown]
# Training function for the proposed model

# %%
def train_CMMD(model_dpc, epochs):
    opt = torch.optim.Adam(model_dpc.parameters(),lr = .000001)
    train_loss_epochs = torch.empty((epochs)).to(device)
    scheduler = lr_scheduler.StepLR(opt, step_size = 50, gamma=0.95, verbose = True)
    for epoch in range(epochs):
        print(epoch)
        a=1
        b=1
        c=10
        i=0
        train_cum_loss = 0
        for batch,params in Train_dl:
            s = batch
            params = params[:,0:2]
            #print("params",params.shape)
            batch_size = s.shape[0]
            x1 = params[:,0] # since params is taking new set of values every iterations 
            #print("omega",omega.shape)
            x2 =  params[:,1]
            opt.zero_grad()
            s_hat,s_hat_dot,zp = model_dpc(batch_size=batch_size, params = params, n=1000)
            i=+1
            loss_CMMD = CMMD_loss(s, s_hat, params, params)
            loss_rec = ((s - s_hat)**2).sum()
            loss = a*loss_CMMD 
            train_cum_loss+=loss
            loss.backward()
            opt.step()
        scheduler.step()
        train_loss_epochs[epoch] = train_cum_loss/2000 ########bATCH_SIZE
        print("loss_CMMD",loss_CMMD)
        print("loss_rec",loss_rec)
    return model_dpc, train_loss_epochs,opt

# %% [markdown]
# Training function for pure-data driven model

# %%
def train_CMMD_new(model_dpc, epochs):
    opt = torch.optim.Adam(model_dpc.parameters(),lr = .001)
    train_loss_epochs = torch.empty((epochs)).to(device)
    scheduler = lr_scheduler.StepLR(opt, step_size = 100, gamma=0.99, verbose = True)
    for epoch in range(epochs):
        print(epoch)
        a=100
        b=1
        c=10
        i=0
        n = 1000
        train_cum_loss = 0
        for batch,params in Train_dl:
            s = batch
            params = params[:,0:2]
            #print("params",params.shape)
            batch_size = s.shape[0]
            s_hat = torch.zeros((batch_size,n), dtype = float).to(device)
            x1 = params[:,0] # since params is taking new set of values every iterations 
            #print("omega",omega.shape)
            x2 =  params[:,1]
            opt.zero_grad()
            for t in range(1000):
                time = t*dt*torch.ones((batch_size,1), dtype = float).to(device)
                s_hat[:,t] = model(batch_size=batch_size, params = params, time = time)
            i=+1
            loss_CMMD = CMMD_loss(s, s_hat, params, params)
            loss_rec = ((s - s_hat)**2).sum()
            loss = a *loss_CMMD + b*loss_rec 
            train_cum_loss+=loss
            loss.backward()
            opt.step()
        scheduler.step()
        train_loss_epochs[epoch] = train_cum_loss/2000 ########bATCH_SIZE
        print("loss_CMMD",loss_CMMD)
        print("loss_rec",loss_rec)
    return model, train_loss_epochs,opt

# %% [markdown]
# Training with combined CMMD and MSE as loss function

# %%
def train_Comb(model_dpc, epochs):
    opt = torch.optim.Adam(model_dpc.parameters(),lr = .0001)
    train_loss_epochs = torch.empty((epochs)).to(device)
    scheduler = lr_scheduler.StepLR(opt, step_size =500, gamma=0.99, verbose = True)
    for epoch in range(epochs):
        print(epoch)
        a=100
        b=1
        c=10
        i=0
        train_cum_loss = 0
        for batch,params in Train_dl:
           s = batch
           params = params[:,0:2]
           #print("params",params.shape)
           batch_size = s.shape[0]
           x1 = params[:,0] # since params is taking new set of values every iterations 
           #print("omega",omega.shape)
           x2 =  params[:,1]
           opt.zero_grad()
           s_hat,s_hat_dot,zp = model_dpc(batch_size=batch_size, params = params, n=1000)
           i=+1
           loss_CMMD = CMMD_loss(s, s_hat, params, params)
           loss_rec = ((s - s_hat)**2).sum()
           loss = a*loss_CMMD + b*loss_rec
           train_cum_loss+=loss
           loss.backward()
           opt.step()
        scheduler.step()
        train_loss_epochs[epoch] = train_cum_loss/2000 ########bATCH_SIZE
        print("loss_CMMD",loss_CMMD)
        print("loss_rec",loss_rec)
    return model_dpc, train_loss_epochs,opt

# %% [markdown]
# Test function for the proposed DPC model

# %%
def test1(model_dpc,n):
    x1=np.random.uniform(0.1,0.5,1500)
    x2=np.random.uniform(5,50,1500)
    t = np.linspace(0,1,1000)
    dt = t[2]-t[1]
    S = np.zeros([1500,n])
    S_dot = np.zeros([1500,n])
    prm_test =np.zeros([1500,2]) 
    for i in range(1500):
        q1 = x1[i]
        q2 = x2[i]
        param = [q1,q2]
        S[i,:],S_dot[i,:] = Euler_Maruyama(param,dt,n)
        prm_test[i] = param
    print(S.shape)
    print(prm_test.shape)
    test_data1 = torch.from_numpy(S).to(device) 
    test_prm1 = torch.from_numpy(prm_test).to(device)
    Test_data1 = TensorDataset(test_data1,test_prm1)
    Test_dl_1 = DataLoader(Test_data1, batch_size=50, shuffle=False)
    with torch.no_grad():  
        s_full =  torch.empty(1500,n)
        s_hat_full =  torch.empty(1500,n)
        parameters =  torch.empty(1500,2) 
        i=0
        for batch,p in Test_dl_1:
            s = batch
            #print("s_shape",s.shape)
            batch_size = s.shape[0]
            parameters[i*batch_size:(i+1)*batch_size,:] = p
            #print(batch_size)
            s_full[i*batch_size:(i+1)*batch_size,:] = s
            s_hat, s_hat_dot, zp = model_dpc(batch_size=batch_size, params = p, n=n)
            s_hat_full[i*batch_size:(i+1)*batch_size,:] = s_hat
            i+=1
        x_hat = s_hat_full.cpu()
        X_hat = x_hat.detach().numpy()
        x = s_full.cpu()
        X= x.detach().numpy()
        er = mae = np.absolute(np.subtract(X_hat, X)).mean() 

    return er,parameters,X_hat,X

# %% [markdown]
# Test function for the all the models combined i.e the DPC model, pure physics and pure data driven model

# %%
def test2(model_dpc, model, n):
    x1=np.random.uniform(0.1,0.5,1500)
    x2=np.random.uniform(5,50,1500)
    t = np.linspace(0,1,1000)
    dt = t[2]-t[1]
    S = np.zeros([1500,n])
    S_dot = np.zeros([1500,n])
    prm_test =np.zeros([1500,2]) 
    for i in range(1500):
        q1 = x1[i]
        q2 = x2[i]
        param = [q1,q2]
        S[i,:],S_dot[i,:] = Euler_Maruyama(param,dt,n)
        prm_test[i] = param
    print(S.shape)
    print(prm_test.shape)
    test_data1 = torch.from_numpy(S).to(device) 
    test_prm1 = torch.from_numpy(prm_test).to(device)
    Test_data1 = TensorDataset(test_data1,test_prm1)
    Test_dl_1 = DataLoader(Test_data1, batch_size=1500, shuffle=False)
    with torch.no_grad():  
        s_full =  torch.empty(1500,n)
        s_hat_full =  torch.empty(1500,n)
        s_hat_full_data = torch.empty(1500,n)
        s_hat_full_physics = torch.empty(1500,n)
        parameters =  torch.empty(1500,2) 
        i=0
    for batch,p in Test_dl_1:
        s = batch
        #print("s_shape",s.shape)
        batch_size = s.shape[0]
        parameters[i*batch_size:(i+1)*batch_size,:] = p
        #print(batch_size)
        s_full[i*batch_size:(i+1)*batch_size,:] = s
        s_hat, s_hat_dot, zp = model_dpc(batch_size=batch_size, params = p, n=n)
        for t in range(n):
            time = t*dt*torch.ones((batch_size,1), dtype = float).to(device)
            s_hat_full_data[:,t] = model(batch_size=batch_size, params = p, time = time)   
        s_hat_full[i*batch_size:(i+1)*batch_size,:] = s_hat
        s_hat_full_physics, s_hat_dot_full_physics = Physics_pure(p,batch_size, dt, n) 
        i+=1
    x_hat = s_hat_full.cpu()
    X_hat = x_hat.detach().numpy()
    x_hat_data = s_hat_full_data.cpu()
    X_hat_data = x_hat_data.detach().numpy()
    x_hat_physics = s_hat_full_physics.cpu()
    X_hat_physics = x_hat_physics.detach().numpy()
    x = s_full.cpu()
    X= x.detach().numpy()
    er = mae = np.absolute(np.subtract(X_hat, X)).mean() 

    return er, parameters, X_hat, X_hat_data, X_hat_physics, X

# %% [markdown]
# Main: Training of the proposed model till convergence is reached

# %%
# No of epochs for training
epochs = 750

# lambda1 and beta1 are the parameters in the kernel function used to define the CMMD loss funct
lambda1 = torch.tensor(-0.5, requires_grad = True).to(device)
beta1 = torch.tensor(4.0, requires_grad = True).to(device)

#Included in the training process
lambda1 = torch.nn.Parameter(lambda1)
beta1 = torch.nn.Parameter(beta1)
model_dpc = DNN().to(device)
model_dpc.register_parameter('lanbda11',lambda1)
model_dpc.register_parameter('beta1',beta1)

#Training
model_dpc,train_loss_epochs,opt= train_CMMD(model_dpc.double(),epochs)

#plotting training loss vs number of epochs at the end of the training
epochs_array = np.linspace(0,epochs,epochs)
train_loss_epochs= train_loss_epochs.cpu()
train_loss_epochs= train_loss_epochs.detach().numpy()
fig1=plt.figure(1)
plt.plot(epochs_array ,train_loss_epochs, label="training_loss")
plt.xlabel("Epochs")
plt.ylabel("Training loss")
# Out:
# Adjusting learning rate of group 0 to 1.0000e-07.
# 0
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6802, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(262.3343, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 1
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6781, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(263.3272, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 2
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6801, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(255.2827, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 3
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6784, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(266.0750, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 4
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6751, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(265.9109, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 5
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6805, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(265.9319, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 6
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6639, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(266.2222, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 7
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6709, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(275.6881, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 8
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6442, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(257.4693, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 9
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6516, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(264.7519, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 10
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6579, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(263.3794, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 11
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6542, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(260.6928, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 12
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6457, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(262.5063, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 13
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6538, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(252.0028, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 14
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6373, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(274.2413, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 15
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6361, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(261.9926, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 16
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6354, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(281.8550, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 17
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6451, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(259.8420, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 18
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6178, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(298.7834, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 19
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6439, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(249.7893, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 20
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6388, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(254.7352, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 21
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6215, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(287.0992, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 22
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6150, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(262.4054, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 23
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6020, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(264.6866, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 24
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6271, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(248.7218, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 25
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6089, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(287.9306, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 26
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.5997, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(273.3719, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 27
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.5736, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(247.6379, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 28
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6122, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(290.5303, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 29
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.5563, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(263.2967, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 30
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.6077, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(285.5557, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 31
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.5850, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(267.2100, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 32
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.5538, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(305.1287, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 33
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.5597, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(299.0902, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 34
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.5255, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(305.1206, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 35
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.5523, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(281.2859, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 36
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.5553, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(306.8990, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 37
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.5247, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(284.0181, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 38
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.5300, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(312.7407, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 39
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.5110, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(317.3401, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 40
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.5105, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(300.6925, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 41
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.4875, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(307.1500, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 42
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.4865, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(327.0760, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 43
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.4733, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(293.6097, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 44
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.4699, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(339.3817, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 45
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.4716, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(315.0154, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 46
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.4910, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(308.9468, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 47
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.4682, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(303.4091, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 48
# Adjusting learning rate of group 0 to 1.0000e-07.
# loss_CMMD tensor(0.4586, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(283.1781, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 49
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.4705, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(344.4310, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 50
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.4673, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(343.2732, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 51
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.4752, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(298.5932, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 52
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.4227, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(335.7126, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 53
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.4932, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(297.9333, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 54
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.4095, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(286.5675, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 55
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.4275, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(329.2536, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 56
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.4067, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(312.9381, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 57
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.4211, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(338.9973, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 58
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.4142, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(255.5126, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 59
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.4344, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(286.0469, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 60
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.4034, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(337.7303, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 61
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.3670, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(358.2789, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 62
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.3502, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(341.2527, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 63
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.3691, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(309.5994, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 64
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.4302, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(284.8521, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 65
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.3825, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(319.1794, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 66
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.4599, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(331.8273, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 67
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.3413, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(351.7909, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 68
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.3994, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(353.9954, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 69
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.3422, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(254.5843, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 70
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.2863, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(316.1139, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 71
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.3423, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(307.8476, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 72
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.3584, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(337.3645, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 73
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.3574, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(376.1999, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 74
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.2833, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(381.6593, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 75
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.4287, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(321.3273, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 76
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.3619, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(342.2958, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 77
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.3238, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(426.3672, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 78
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.2756, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(334.6096, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 79
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.3451, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(334.7809, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 80
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.3789, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(347.2303, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 81
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.2699, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(419.3230, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 82
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.3407, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(299.6512, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 83
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.3254, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(392.0653, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 84
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.3439, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(410.5520, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 85
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.3445, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(400.1562, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 86
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.3206, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(370.0500, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 87
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.3085, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(345.0558, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 88
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.2661, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(392.7659, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 89
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.2520, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(354.6741, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 90
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.3234, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(363.4278, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 91
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.3360, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(373.2783, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 92
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.3199, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(348.9683, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 93
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.2745, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(391.8792, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 94
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.2552, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(385.8677, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 95
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.1910, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(425.8059, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 96
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.3298, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(299.8447, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 97
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.2437, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(427.8520, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 98
# Adjusting learning rate of group 0 to 9.5000e-08.
# loss_CMMD tensor(0.2299, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(494.1006, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 99
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.3250, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(335.2963, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 100
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2973, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(370.5332, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 101
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2787, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(281.6148, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 102
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.1649, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(410.6997, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 103
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2406, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(315.8128, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 104
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2672, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(393.8452, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 105
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2954, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(315.2075, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 106
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2167, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(439.4814, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 107
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2976, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(400.1945, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 108
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2910, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(355.0951, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 109
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2985, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(302.3668, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 110
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2452, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(425.4429, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 111
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2207, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(401.3325, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 112
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2679, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(354.9954, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 113
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.3057, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(397.8595, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 114
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2152, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(417.1232, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 115
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.1826, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(438.1219, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 116
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2266, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(370.7997, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 117
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2051, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(341.2963, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 118
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2341, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(353.3403, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 119
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.1613, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(545.7784, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 120
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2739, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(348.4364, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 121
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2688, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(387.1896, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 122
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2066, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(462.2442, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 123
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2114, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(487.3216, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 124
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.1466, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(477.4593, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 125
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2182, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(494.6702, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 126
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2916, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(478.2981, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 127
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2419, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(399.3049, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 128
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.1795, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(401.8284, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 129
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2272, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(398.2949, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 130
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2512, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(445.6680, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 131
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.1491, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(544.0873, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 132
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2785, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(330.8405, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 133
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2041, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(427.3367, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 134
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2072, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(392.4169, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 135
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2253, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(439.9904, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 136
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.1470, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(367.9467, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 137
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2081, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(457.6299, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 138
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2630, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(461.1571, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 139
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2578, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(264.5370, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 140
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.1971, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(453.3713, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 141
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.1640, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(393.5446, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 142
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2448, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(413.5334, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 143
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.1781, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(431.1915, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 144
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2154, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(452.1811, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 145
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2161, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(451.2562, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 146
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.1991, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(444.9856, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 147
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.2342, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(361.7958, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 148
# Adjusting learning rate of group 0 to 9.0250e-08.
# loss_CMMD tensor(0.1701, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(409.6175, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 149
# Adjusting learning rate of group 0 to 8.5737e-08.
# loss_CMMD tensor(0.1498, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(655.0605, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# Text(0, 0.5, 'Training loss')

# %%
torch.save(model_dpc.state_dict(), 'PIDecoder_DVP_2_2k_Pdiffusion_2')

# %% [markdown]
# Training of pure data-driven model

# %%
epochs = 150
lambda1 = torch.tensor(-0.5, requires_grad = True).to(device)
beta1 = torch.tensor(4.0, requires_grad = True).to(device)
lambda1 = torch.nn.Parameter(lambda1)
beta1 = torch.nn.Parameter(beta1)
model = Datadriven().to(device)
model.register_parameter('lanbda11',lambda1)
model.register_parameter('beta1',beta1)

model,train_loss_epochs,opt= train_CMMD_new(model.double(),epochs)
epochs_array = np.linspace(0,epochs,epochs)
train_loss_epochs= train_loss_epochs.cpu()
train_loss_epochs= train_loss_epochs.detach().numpy()
fig1=plt.figure(1)
plt.plot(epochs_array ,train_loss_epochs, label="training_loss")
plt.xlabel("Epochs")
plt.ylabel("Training loss")
# Out:
# Adjusting learning rate of group 0 to 1.0000e-03.
# 0
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0572, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(18443.3671, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 1
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0593, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(17507.2358, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 2
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0594, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(17468.2097, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 3
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0591, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(17444.6446, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 4
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0596, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(17463.4430, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 5
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0581, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(17428.2434, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 6
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0584, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(17424.1152, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 7
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0550, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(17847.5046, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 8
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0578, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(18144.3908, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 9
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0604, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(17281.2640, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 10
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0578, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(17891.2742, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 11
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0346, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(21942.2877, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 12
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0537, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(16727.8553, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 13
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(0.9889, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(12531.2679, device='cuda:0', dtype=torch.float64,
#        grad_fn=<SumBackward0>)
# 14
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(0.9542, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(7234.4881, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 15
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(0.8410, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(4556.5003, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 16
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0031, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(4998.1551, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 17
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(0.9466, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3630.9420, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 18
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0162, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(4322.2810, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 19
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(0.9798, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3205.0046, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 20
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(0.9992, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3367.6113, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 21
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0039, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3438.0153, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 22
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0111, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3469.9639, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 23
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0146, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3585.7327, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 24
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0237, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3649.7546, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 25
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0208, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3615.1274, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 26
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0241, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3495.4850, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 27
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0257, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(4343.6132, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 28
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0272, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3308.2002, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 29
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0295, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(4145.7678, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 30
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0310, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(4244.3763, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 31
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0326, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(4182.4558, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 32
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0348, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3965.7221, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 33
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0374, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3913.8897, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 34
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0357, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3890.4335, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 35
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0392, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3559.7377, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 36
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0420, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3379.1550, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 37
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0407, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3145.5573, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 38
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0402, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3010.1061, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 39
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0418, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2966.4305, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 40
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0430, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2961.1792, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 41
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0429, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2984.0227, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 42
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0441, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3007.2664, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 43
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0459, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3024.3244, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 44
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0474, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3030.2547, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 45
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0437, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3042.3611, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 46
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0471, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3030.3944, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 47
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0494, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3038.0606, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 48
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0482, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3030.9461, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 49
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0459, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3035.8758, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 50
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0499, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3041.4974, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 51
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0495, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3038.6118, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 52
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0490, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3054.6723, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 53
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0502, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3040.8092, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 54
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0494, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3061.9959, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 55
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0524, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3049.7245, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 56
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0505, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3064.4129, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 57
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0512, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3045.4394, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 58
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0520, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3074.3025, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 59
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0540, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3048.1231, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 60
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0523, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3074.3035, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 61
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0530, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3050.0134, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 62
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0518, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3085.6779, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 63
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0530, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3051.1038, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 64
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0533, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3098.3421, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 65
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0520, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3049.4853, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 66
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0525, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3111.3721, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 67
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0538, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3049.0089, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 68
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0533, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3125.6578, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 69
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0531, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3054.3183, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 70
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0542, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3138.4404, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 71
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0539, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3058.5258, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 72
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0526, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3144.1154, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 73
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0512, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3068.4491, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 74
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0529, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3156.8256, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 75
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0538, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3088.7797, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 76
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0533, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3176.8313, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 77
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0537, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3096.0842, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 78
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0548, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3178.1847, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 79
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0532, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3085.7066, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 80
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0527, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3187.4373, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 81
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0514, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3076.9721, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 82
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0544, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3195.2241, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 83
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0537, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3063.4674, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 84
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0541, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3190.0900, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 85
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0525, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3050.4340, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 86
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0547, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3204.5562, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 87
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0550, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3028.9488, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 88
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0532, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3174.2659, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 89
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0536, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3013.9607, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 90
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0540, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3175.8565, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 91
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0558, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3026.3051, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 92
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0536, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3181.9842, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 93
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0538, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2996.9020, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 94
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0554, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3161.9681, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 95
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0540, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2970.9279, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 96
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0553, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3151.2150, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 97
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0529, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2972.9062, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 98
# Adjusting learning rate of group 0 to 1.0000e-03.
# loss_CMMD tensor(1.0534, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3141.5210, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 99
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0542, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2986.2080, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 100
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0538, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3237.0219, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 101
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0556, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2945.6172, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 102
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0539, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3154.4685, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 103
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0556, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2894.6770, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 104
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0527, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3137.7626, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 105
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0543, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2910.1301, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 106
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0564, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3121.0074, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 107
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0546, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2912.0539, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 108
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0551, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3099.6323, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 109
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0534, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2947.9725, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 110
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0514, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3131.8038, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 111
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0526, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2913.2667, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 112
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0533, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3113.0490, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 113
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0557, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2913.9668, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 114
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0525, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3123.7576, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 115
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0544, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2866.1146, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 116
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0527, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3143.5413, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 117
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0556, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2880.7578, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 118
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0534, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3097.4171, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 119
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0548, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2898.7791, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 120
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0548, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3109.8538, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 121
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0529, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2885.4284, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 122
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0532, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3078.8248, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 123
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0532, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2897.0714, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 124
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0526, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3115.8461, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 125
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0540, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2886.3513, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 126
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0526, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3091.4269, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 127
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0537, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2880.2498, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 128
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0545, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3023.3067, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 129
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0555, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2896.5312, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 130
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0552, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3015.3567, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 131
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0551, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2928.4180, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 132
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0558, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3048.4726, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 133
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0547, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2929.7522, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 134
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0543, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3051.1491, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 135
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0535, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2887.6807, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 136
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0559, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3056.3781, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 137
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0549, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2850.0143, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 138
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0557, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2989.6559, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 139
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0553, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2853.2922, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 140
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0564, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2922.4085, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 141
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0549, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2872.6525, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 142
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0539, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2857.4711, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 143
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0516, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2921.6634, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 144
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0491, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2879.6801, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 145
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0550, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3031.5235, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 146
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0567, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2895.2640, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 147
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0562, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3043.0232, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 148
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0514, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(2911.1078, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# 149
# Adjusting learning rate of group 0 to 9.9000e-04.
# loss_CMMD tensor(1.0550, device='cuda:0', dtype=torch.float64, grad_fn=<SqrtBackward0>)
# loss_rec tensor(3148.6507, device='cuda:0', dtype=torch.float64, grad_fn=<SumBackward0>)
# Text(0, 0.5, 'Training loss')

# %%
torch.save(model.state_dict(), 'PIDecoder_DVP_2_2k_Pdiffusion_data2')

# %% [markdown]
# Plots of pdf for all the models within and outside the training window

# %%
with torch.no_grad():  
    device = torch.device("cuda")
    lambda1 = torch.tensor(-0.5, requires_grad = True).to(device)
    beta1 = torch.tensor(4.0, requires_grad = True).to(device)
    lambda1 = torch.nn.Parameter(lambda1)
    beta1 = torch.nn.Parameter(beta1)
    model_dpc = DNN().to(device)
    model_dpc.register_parameter('lanbda11',lambda1)
    model_dpc.register_parameter('beta1',beta1)
    model_dpc.load_state_dict(torch.load('PIDecoder_DVP_2_2k_Pdiffusion_2'))
    model_dpc.to(device)
    model = Datadriven().to(device)
    model.register_parameter('lanbda11',lambda1)
    model.register_parameter('beta1',beta1) 
    model.load_state_dict(torch.load('PIDecoder_DVP_2_2k_Pdiffusion_data2'))
    nt =10000
    mae,prm, X_hat, X_hat_data, X_hat_physics, X = test2(model_dpc.double(), model.double(), n=nt) 
    prm = prm.cpu()
    prm = prm.detach().numpy()
    
    from scipy.stats import gaussian_kde
    density = gaussian_kde(X[:,915])
    density_1 = gaussian_kde(X_hat[:,915] )
    density_2 = gaussian_kde( X_hat_data[:,915])
    density_3 = gaussian_kde(X_hat_physics[:,915])
    
    density_p = gaussian_kde(X[:,8778])
    density_p_1 = gaussian_kde(X_hat[:,8778] )
    density_p_2 = gaussian_kde( X_hat_data[:,8778])
    density_p_3 = gaussian_kde(X_hat_physics[:,8778])
    
  
    xs = np.linspace(-2,9,100)
    ys = np.linspace(-2,9,20)
    zs = np.linspace(-2,3,300)
    
    plt.figure(1) 
    plt.plot(zs,density(zs),"*",color ="k", label = "Ground Truth")
    plt.plot(xs,density_1(xs),"r", label = "Proposed approach")
    plt.plot(ys,density_2(ys),"-^",color ="m",label = "Data only")
    plt.plot(xs,density_3(xs),"-v",label = "Incomplete physics only")
    plt.ylabel('Probability density function')
    plt.xlabel('QoI')
    plt.legend()
    plt.savefig('multi_PI_DVP_PDiffusion.pdf')
    
    plt.figure(2) 
    plt.plot(zs,density_p(zs),"*",color ="k", label = "Ground Truth")
    plt.plot(xs,density_p_1(xs),"g", label = "Proposed approach")
    plt.plot(ys,density_p_2(ys),"-^",color ="m",label = "Data only")
    plt.plot(xs,density_p_3(xs),"-v",label = "Incomplete physics only")
    plt.ylabel('Probability density function')
    plt.xlabel('QoI')
    plt.legend()
    plt.savefig('multi_PI_DVP_PDiffusion_pred.pdf')
# Out:
# (1500, 10000)
# (1500, 2)

# %% [markdown]
# Hellinger distance

# %%
def Hellinger(pdf1,pdf2):
    output =np.sum(np.power(np.sqrt(pdf1)-np.sqrt(pdf2),2))
    return output

# %%
from scipy.stats import gaussian_kde
with torch.no_grad():  
    device = torch.device("cuda")
    lambda1 = torch.tensor(-0.5, requires_grad = True).to(device)
    beta1 = torch.tensor(4.0, requires_grad = True).to(device)
    lambda1 = torch.nn.Parameter(lambda1)
    beta1 = torch.nn.Parameter(beta1)
    model_dpc = DNN().to(device)
    model_dpc.register_parameter('lanbda11',lambda1)
    model_dpc.register_parameter('beta1',beta1)
    model_dpc.load_state_dict(torch.load('PIDecoder_DVP_2_2k_Pdiffusion_2'))
    model_dpc.to(device)
    model = Datadriven().to(device)
    model.register_parameter('lanbda11',lambda1)
    model.register_parameter('beta1',beta1) 
    model.load_state_dict(torch.load('PIDecoder_DVP_2_2k_Pdiffusion_data2'))
    
    nt =10000
    x = np.linspace(-10,10,350)
    y = np.linspace(-10,10,350)
    z = np.linspace(-10,10,350)
    p = np.linspace(-10,10,350)
    er_dpc=np.zeros([nt])
    er_pd=np.zeros([nt])
    er_pp=np.zeros([nt])
    mae,prm, X_hat, X_hat_data, X_hat_physics, X=test2(model_dpc.double(), model.double(), n=nt)
    for i in range(1,nt):
        density = gaussian_kde(X[:,i])
        density_DPC = gaussian_kde(X_hat[:,i])
        density_PD = gaussian_kde(X_hat_data[:,i])
        density_PP = gaussian_kde(X_hat_physics[:,i])
        er_dpc[i] = Hellinger(density(x),density_DPC(x))
        er_pd[i] = Hellinger(density(x),density_PD(x))
        er_pp[i] = Hellinger(density(x),density_PP(x))
    
    er_dpc_mean = np.mean(er_dpc)
    er_pd_mean = np.mean(er_pd)
    er_pp_mean = np.mean(er_pp)
    print(er_dpc_mean)
    print(er_pd_mean)
    print(er_pp_mean)
# Out:
# (1500, 10000)
# (1500, 2)
# 0.026698093948739666
# 23.894281131759907
# 1.386252337200171

# %%
er_dpc_mean = np.zeros(5)
er_pd_mean = np.zeros(5)
er_pp_mean= np.zeros(5)
for k in range(5):
    from scipy.stats import gaussian_kde
    with torch.no_grad():  
        device = torch.device("cuda")
        lambda1 = torch.tensor(-0.5, requires_grad = True).to(device)
        beta1 = torch.tensor(4.0, requires_grad = True).to(device)
        lambda1 = torch.nn.Parameter(lambda1)
        beta1 = torch.nn.Parameter(beta1)
        model_dpc = DNN().to(device)
        model_dpc.register_parameter('lanbda11',lambda1)
        model_dpc.register_parameter('beta1',beta1)
        model_dpc.load_state_dict(torch.load('PIDecoder_DVP_2_2k_Pdiffusion_2'))
        model_dpc.to(device)
        model = Datadriven().to(device)
        model.register_parameter('lanbda11',lambda1)
        model.register_parameter('beta1',beta1) 
        model.load_state_dict(torch.load('PIDecoder_DVP_2_2k_Pdiffusion_data2'))

        nt =10000
        x = np.linspace(-10,10,350)
        y = np.linspace(-10,10,350)
        z = np.linspace(-10,10,350)
        p = np.linspace(-10,10,350)
        er_dpc=np.zeros([nt])
        er_pd=np.zeros([nt])
        er_pp=np.zeros([nt])
        mae,prm, X_hat, X_hat_data, X_hat_physics, X=test2(model_dpc.double(), model.double(), n=nt)
        for i in range(1,nt):
            density = gaussian_kde(X[:,i])
            density_DPC = gaussian_kde(X_hat[:,i])
            density_PD = gaussian_kde(X_hat_data[:,i])
            density_PP = gaussian_kde(X_hat_physics[:,i])
            er_dpc[i] = Hellinger(density(x),density_DPC(y))
            er_pd[i] = Hellinger(density(x),density_PD(z))
            er_pp[i] = Hellinger(density(x),density_PP(p))

        er_dpc_mean[k] = np.mean(er_dpc)
        er_pd_mean[k] = np.mean(er_pd)
        er_pp_mean[k] = np.mean(er_pp)
        print("dpc",er_dpc_mean)
        print("pd",er_pd_mean)
        print("pp",er_pp_mean)
Error_dpc =  np.mean(er_dpc_mean)
Error_pd =  np.mean(er_pd_mean)
Error_pp =  np.mean(er_pp_mean)

print("Error_dpc",Error_dpc)
print("Error_dpc",Error_pd)
print("Error_dpc",Error_pp)
# Out:
# (1500, 10000)
# (1500, 2)
# dpc [0.02500048 0.         0.         0.         0.        ]
# pd [23.77519361  0.          0.          0.          0.        ]
# pp [1.33389666 0.         0.         0.         0.        ]
# (1500, 10000)
# (1500, 2)
# dpc [0.02500048 0.02948924 0.         0.         0.        ]
# pd [23.77519361 23.82117985  0.          0.          0.        ]
# pp [1.33389666 1.38036924 0.         0.         0.        ]
# (1500, 10000)
# (1500, 2)
# dpc [0.02500048 0.02948924 0.02343168 0.         0.        ]
# pd [23.77519361 23.82117985 23.82759428  0.          0.        ]
# pp [1.33389666 1.38036924 1.27013173 0.         0.        ]
# (1500, 10000)
# (1500, 2)
# dpc [0.02500048 0.02948924 0.02343168 0.02801526 0.        ]
# pd [23.77519361 23.82117985 23.82759428 23.7521088   0.        ]
# pp [1.33389666 1.38036924 1.27013173 1.12863397 0.        ]
# (1500, 10000)
# (1500, 2)
# dpc [0.02500048 0.02948924 0.02343168 0.02801526 0.0296452 ]
# pd [23.77519361 23.82117985 23.82759428 23.7521088  23.64464223]
# pp [1.33389666 1.38036924 1.27013173 1.12863397 1.37000834]
# Error_dpc 0.027116373204223367
# Error_dpc 23.764143753467557
# Error_dpc 1.2966079897229068
